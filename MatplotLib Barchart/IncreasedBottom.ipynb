# %%
'''
@Author: Subhadeep Bhattacharjee
@Date: 2021:12:07 22:50
@Title: To create a bar chart and increase bottom margin

'''

# %%
from matplotlib import pyplot as plt


lang = ['Java' , 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]


plt.xlabel('Languages')
plt.ylabel('Popularity')
plt.title('Language popularity')
plt.margins(0.1)                           #this is used to add padding. always in float

width = [0.3,0.2,0.5,0.8,0.2,0.4]
y_pos = [0,.8,1.5,3,5,6]

# Create bars
plt.bar(y_pos, popularity, width=width)
plt.xticks(y_pos, lang, rotation = '90')

for i,g in enumerate(popularity):
    g= float(g)
    plt.text(i, g+1.5, f'{g:.3f}', ha = 'center', fontsize = '10', va = 'bottom')
    
plt.subplots_adjust(bottom = 0.2)

plt.ylim(0,30)
plt.show()
