# %%
'''
@Author: Subhadeep Bhattacharjee
@Date: 2021:12:07 21:50
@Title: To create a bar chart with float values above each bar and give blue border

'''

# %%
from matplotlib import pyplot as plt


lang = ['Java' , 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]


plt.xlabel('Languages')
plt.ylabel('Popularity')
plt.title('Language popularity')
plt.margins(0.1)                           #this is used to add padding. always in float
plt.bar(lang, popularity, width= 0.6, edgecolor = 'blue', color = 'orange', linewidth = 3)

for i,g in enumerate(popularity):
    g= float(g)
    plt.text(i, g+1.5, f'{g:.3f}', color = 'black', ha = 'center', fontsize = '10', va = 'bottom')   

plt.ylim(0,30)
plt.show()
