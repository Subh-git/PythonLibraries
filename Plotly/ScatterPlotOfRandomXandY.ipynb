# %%
'''
@Author: Subhadeep Bhattacharjee
@Date: 2021-12-09 18:35
@Title: Plotly scatter plot of 1000 random x and y coordinates.

'''

# %%
import pandas as pd
import plotly.express as px
import numpy as np


x_arr = np.random.randn(1000)
y_arr = np.random.randn(1000)

px.scatter(x= x_arr, y= y_arr)
